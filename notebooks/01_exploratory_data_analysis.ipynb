# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ## NIH Chest X-ray Dataset
#
# This notebook analyzes the class distributions and image properties of the dataset.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from backend.ml import clean_data, eda_utils
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load and Clean Data
train, val, test, labels = clean_data.clean_and_split()

print(f"Training samples: {len(train)}")
print(f"Validation samples: {len(val)}")
print(f"Testing samples: {len(test)}")

# %%
# Plot Distributions
full_df = pd.concat([train, val, test])
eda_utils.plot_disease_distributions(full_df, labels)

# %%
# Plot Co-occurrence
eda_utils.plot_cooccurrence(full_df, labels)
